# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#creating datbase connection
engine = create_engine(
    "mysql+pymysql://analytics:password@localhost:3306/inventory"
)

# %%
#checking tables present in the databse
query = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'inventory'
"""

tables_df = pd.read_sql_query(query, engine)
tables_df.columns = tables_df.columns.str.lower()
tables_df
# Out:
#              table_name
# 0       begin_inventory
# 1         end_inventory
# 2        purchase_price
# 3             purchases
# 4                 sales
# 5        vendor_invoice
# 6  vendor_sales_summary

# %%
for current_table_name in tables_df['table_name']:

    query = f"""
    SELECT COUNT(*) AS row_count
    FROM {current_table_name}
    """

    count_df = pd.read_sql(query, engine)

    row_count = count_df['row_count'].iloc[0]

    print(current_table_name, "->", row_count)
# Out:
# begin_inventory -> 206529
# end_inventory -> 224489
# purchase_price -> 12261
# purchases -> 2372474
# sales -> 12825363
# vendor_invoice -> 5543
# vendor_sales_summary -> 10692

# %%
# Change the filename to your 1.5GB file name
file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/begin_inventory.csv'

with open(file_path, 'r') as f:
    print("Headers:", f.readline())  # This prints line 1
    print("Data Row:", f.readline()) # This prints line 2 so I can see the data types
# Out:
# Headers: InventoryId,Store,City,Brand,Description,Size,onHand,Price,startDate
#
# Data Row: 1_HARDERSFIELD_58,1,HARDERSFIELD,58,Gekkeikan Black & Gold Sake,750mL,8,12.99,2024-01-01

# %%
# Change the filename to your 1.5GB file name
file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/end_inventory.csv'

with open(file_path, 'r') as f:
    print("Headers:", f.readline())  # This prints line 1
    print("Data Row:", f.readline()) # This prints line 2 so I can see the data types
# Out:
# Headers: InventoryId,Store,City,Brand,Description,Size,onHand,Price,endDate
#
# Data Row: 1_HARDERSFIELD_58,1,HARDERSFIELD,58,Gekkeikan Black & Gold Sake,750mL,11,12.99,2024-12-31

# %%
# Change the filename to your 1.5GB file name
file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/purchase_prices.csv'

with open(file_path, 'r') as f:
    print("Headers:", f.readline())  # This prints line 1
    print("Data Row:", f.readline()) # This prints line 2 so I can see the data types
# Out:
# Headers: Brand,Description,Price,Size,Volume,Classification,PurchasePrice,VendorNumber,VendorName
#
# Data Row: 58,Gekkeikan Black & Gold Sake,12.99,750mL,750,1,9.28,8320,SHAW ROSS INT L IMP LTD

# %%
# Change the filename to your 1.5GB file name
file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/purchases.csv'

with open(file_path, 'r') as f:
    print("Headers:", f.readline())  # This prints line 1
    print("Data Row:", f.readline()) # This prints line 2 so I can see the data types
# Out:
# Headers: InventoryId,Store,Brand,Description,Size,VendorNumber,VendorName,PONumber,PODate,ReceivingDate,InvoiceDate,PayDate,PurchasePrice,Quantity,Dollars,Classification
#
# Data Row: 69_MOUNTMEND_8412,69,8412,Tequila Ocho Plata Fresno,750mL,105,ALTAMAR BRANDS LLC         ,8124,2023-12-21,2024-01-02,2024-01-04,2024-02-16,35.71,6,214.26,1

# %%
# Change the filename to your 1.5GB file name
file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sales.csv'

with open(file_path, 'r') as f:
    print("Headers:", f.readline())  # This prints line 1
    print("Data Row:", f.readline()) # This prints line 2 so I can see the data types
# Out:
# Headers: InventoryId,Store,Brand,Description,Size,SalesQuantity,SalesDollars,SalesPrice,SalesDate,Volume,Classification,ExciseTax,VendorNo,VendorName
#
# Data Row: 1_HARDERSFIELD_1004,1,1004,Jim Beam w/2 Rocks Glasses,750mL,1,16.49,16.49,2024-01-01,750.0,1,0.79,12546,JIM BEAM BRANDS COMPANY

# %%
# Change the filename to your 1.5GB file name
file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/vendor_invoice.csv'

with open(file_path, 'r') as f:
    print("Headers:", f.readline())  # This prints line 1
    print("Data Row:", f.readline()) # This prints line 2 so I can see the data types
# Out:
# Headers: VendorNumber,VendorName,InvoiceDate,PONumber,PODate,PayDate,Quantity,Dollars,Freight,Approval
#
# Data Row: 105,ALTAMAR BRANDS LLC         ,2024-01-04,8124,2023-12-21,2024-02-16,6,214.26,3.47,

# %%
display(pd.read_sql(f"SELECT * FROM {current_table_name} LIMIT 5", engine))
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          26.27        36.99               145080.0            3811251.60
# 1          23.19        28.99               164038.0            3804041.22
# 2          18.24        24.99               187407.0            3418303.68
# 3          16.17        22.99               201682.0            3261197.94
# 4          21.89        29.99               138109.0            3023206.01
#
# ...

# %%
test_query = "SELECT VendorNumber, COUNT(*) FROM purchases GROUP BY VendorNumber LIMIT 5"
print(pd.read_sql_query(test_query, engine))
# Out:
#    VendorNumber  COUNT(*)
# 0           105        57
# 1          4466      2192
# 2           388       266
# 3           480     91846
# 4           516     23510

# %%
purchases_4466 = pd.read_sql_query(f"SELECT * FROM purchases WHERE VendorNumber = 4466", engine)
purchases_4466.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3    38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4  59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
# 4          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
purchase_prices_4466 = pd.read_sql_query(f"SELECT * FROM purchase_price WHERE VendorNumber = 4466", engine)
purchase_prices_4466.head()
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice_4466 = pd.read_sql_query(f"SELECT * FROM vendor_invoice WHERE VendorNumber = 4466", engine)
vendor_invoice_4466.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2          4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3          4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4          4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2023-12-22  2024-02-21        15   140.55     8.57
# 1  2023-12-27  2024-02-26       335  3142.33    16.97
# 2  2024-01-03  2024-02-18        41   383.35     1.99
# 3  2024-01-14  2024-03-11        72   673.20     3.30
# 4  2024-01-19  2024-03-15        79   740.21     3.48

# %%
sales_4466 = pd.read_sql_query(f"SELECT * FROM sales WHERE VendorNo = 4466", engine)
sales_4466.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         12.99       12.99  2024-01-09  1750.0
# 1              1         12.99       12.99  2024-01-12  1750.0
# 2              1         12.99       12.99  2024-01-15  1750.0
# 3              1         12.99       12.99  2024-01-21  1750.0
# 4              1         12.99       12.99  2024-01-23  1750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       1.84      4466  AMERICAN VINTAGE BEVERAGE
# ...

# %%
# Summing up the Dollars and Quantity for our specific Vendor
# This shows us exactly what we've invested in Vendor 4466
purchase_analysis = purchases_4466.groupby('Brand')[['Quantity', 'Dollars', 'Description']].sum()

print("Top Brands for Vendor 4466 by Expenditure:")
display(purchase_analysis.sort_values(by='Dollars', ascending=False).head())
# Out:
# Top Brands for Vendor 4466 by Expenditure:
#        Quantity   Dollars                                        Description
# Brand
# 5255       6215  58110.25  TGI Fridays Ultimte MudslideTGI Fridays Ultimt...
# 3140       4640  51921.60  TGI Fridays Orange DreamTGI Fridays Orange Dre...
# 5215       4923  46325.43  TGI Fridays Long Island IcedTGI Fridays Long I...

# %% [markdown]
# ### Project Data Overview
#
# * **The Purchases Table:** Contains actual purchase data, including the date of purchase, products (Brands) purchased from vendors, the amount paid (in dollars), and the quantity purchased.
# * **The Purchase Price Table:** Provides product-wise actual and purchase prices. The combination of Vendor and Brand is unique here.
# * **The Vendor Invoice Table:** Aggregates data from the purchase table, summarizing quantity and dollar amounts with an additional column for freight. It is unique based on Vendor and PO_Number.
# * **The Sales Table:** Captures actual sales transactions, detailing the brands sold, the quantity, the selling price, and the total revenue earned.

# %% [markdown]
# ### 🎯 Objective: Create a Consolidated Summary Table
# Since our data is currently split across different tables, we need to merge them to see the full picture. Our goal is to combine:
#
# * [x] **Purchase Transactions:** Actual buys made from vendors.
# * [ ] **Sales Transactions:** How much of that product actually sold.
# * [ ] **Freight Costs:** The shipping expenses for each vendor.
# * [ ] **Product Prices:** The actual cost reference from the `purchase_price` table.

# %%
freight_summary = pd.read_sql_query("""
    SELECT VendorNumber, SUM(freight) as FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
""", engine)
freight_summary.head()
# Out:
#    VendorNumber  FreightCost
# 0           105        62.39
# 1          4466       793.91
# 2           388       211.74
# 3           480     89286.27
# 4           516      8510.41

# %%
purchase_data_summary = pd.read_sql_query("""
  SELECT 
     p.VendorNumber, p.VendorName, p.Brand, p.PurchasePrice, 
     pp.Volume, pp.Price as ActualPrice,
     SUM(p.Quantity) as TotalPurchaseQuantity, 
     SUM(p.Dollars) as TotalPurchaseDollars
  FROM purchases p
  JOIN purchase_price pp ON p.Brand = pp.Brand 
  WHERE p.PurchasePrice > 0
  GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.PurchasePrice, pp.Volume, pp.Price
  ORDER BY TotalPurchaseDollars DESC
""", engine)
purchase_data_summary.head()
# Out:
#    VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0          1128  BROWN-FORMAN CORP             1233          26.27   1750
# 1          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 2         17035  PERNOD RICARD USA             8068          18.24   1750
# 3          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 4          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
#
#    ActualPrice  TotalPurchaseQuantity  TotalPurchaseDollars
# 0        36.99               145080.0            3811251.60
# 1        28.99               164038.0            3804041.22
# 2        24.99               187407.0            3418303.68
# 3        22.99               201682.0            3261197.94
# 4        29.99               138109.0            3023206.01

# %%
sales_data_summary = pd.read_sql_query("""
    SELECT 
        VendorNo, 
        Brand, 
        SUM(SalesDollars) as TotalSalesDollars, 
        SUM(SalesPrice) as TotalSalesPrice, 
        SUM(SalesQuantity) as TotalSalesQuantity, 
        SUM(ExciseTax) as TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
""", engine)
sales_data_summary.head()
# Out:
#    VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  \
# 0     12546   1004           15708.97         11365.46               703.0
# 1     12546   1005           32120.82         19349.47               918.0
# 2      2000  10058          293349.46        113447.03             21018.0
# 3     12546   1006            1308.72           323.19               328.0
# 4     10754  10062           18518.71         11417.50              2029.0
#
#    TotalExciseTax
# 0          554.21
# 1          359.97
# 2         2348.27
# 3           17.03
# 4          225.11

# %% [markdown]
# ### 🎯 Objective: Create a Consolidated Summary Table
# Since our data is currently split across different tables, we need to merge them to see the full picture. Our goal is to combine:
#
# * [x] **Purchase Transactions:** Actual buys made from vendors.
# * [x] **Sales Transactions:** How much of that product actually sold.
# * [x] **Freight Costs:** The shipping expenses for each vendor.
# * [x] **Product Prices:** The actual cost reference from the `purchase_price` table.

# %%
vendor_sales_summary = pd.read_sql_query("""
WITH freightSummary AS (
    SELECT 
        VendorNumber, 
        SUM(freight) as FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),
PurchaseSummary AS (
    SELECT 
        p.VendorNumber, 
        p.VendorName, 
        p.Brand, 
        p.Description,
        p.PurchasePrice, 
        pp.Price as ActualPrice,
        SUM(p.Quantity) as TotalPurchaseQuantity, 
        SUM(p.Dollars) as TotalPurchaseDollars
    FROM purchases p
    JOIN purchase_price pp ON p.Brand = pp.Brand 
    WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price
),
SalesSummary AS (
    SELECT 
        VendorNo, 
        Brand, 
        SUM(SalesDollars) as TotalSalesDollars, 
        SUM(SalesPrice) as TotalSalesPrice, 
        SUM(SalesQuantity) as TotalSalesQuantity, 
        SUM(ExciseTax) as TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)
SELECT 
    ps.VendorNumber, 
    ps.VendorName, 
    ps.Brand, 
    ps.Description,
    ps.PurchasePrice, 
    ps.ActualPrice, 
    ps.TotalPurchaseQuantity, 
    ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity, 
    ss.TotalSalesDollars, 
    ss.TotalSalesPrice, 
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss 
    ON ps.VendorNumber = ss.VendorNo AND ps.Brand = ss.Brand
LEFT JOIN freightSummary fs 
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC
""", engine)
display(vendor_sales_summary.head())
display(vendor_sales_summary.tail())
# Out:
#    VendorNumber                   VendorName  Brand              Description  \
# 0          1128  BROWN-FORMAN CORP             1233  Jack Daniels No 7 Black
# 1          4425        MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035  PERNOD RICARD USA             8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC      4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC      3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          26.27        36.99               145080.0            3811251.60
# 1          23.19        28.99               164038.0            3804041.22
# 2          18.24        24.99               187407.0            3418303.68
# 3          16.17        22.99               201682.0            3261197.94
# 4          21.89        29.99               138109.0            3023206.01
#
# ...

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'ActualPrice', 'TotalPurchaseQuantity', 'TotalPurchaseDollars',
#        'TotalSalesQuantity', 'TotalSalesDollars', 'TotalSalesPrice',
#        'TotalExciseTax', 'FreightCost'],
#       dtype='object')

# %% [markdown]
# This query generates a vendor-wise sales and purchase summary, which is valuable for:
#
# ### Performance Optimization:
#
# * The query involves heavy joins and aggregation on large datasets like sales and purchases.
# * Storing the pre-aggregated results avoids repeated expensive computations.
# * Helps in analyzing sales, purchases , and pricing for different vendors and brands.
# * Future benifits of storing this data for faster dashboarding & reporting.
# * Instead of running expensive queries each time , dashboards can fetch data quickly from vendor_sala_summary.

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalSalesPrice          178
# TotalExciseTax           178
# FreightCost                0
# dtype: int64

# %%
vendor_sales_summary['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
# Cleaning
vendor_sales_summary.fillna(0, inplace=True)
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'].str.strip()

# %%
# Gross Profit
vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesDollars'] - vendor_sales_summary['TotalPurchaseDollars']

# %%
# Profit Margin
vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit'] / vendor_sales_summary['TotalSalesDollars']) * 100

# %%
# Stock Turnover
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity'] / vendor_sales_summary['TotalPurchaseDollars']

# %%
# Sales to Purchase Rate
vendor_sales_summary['SalesToPurchaseRate'] = vendor_sales_summary['TotalSalesDollars'] / vendor_sales_summary['TotalPurchaseDollars']

# %%
from sqlalchemy import text

with engine.connect() as conn:
    # Wrap your string inside text()
    query = text("""
    CREATE TABLE IF NOT EXISTS vendor_sales_summary (
        VendorNumber INT,
        VendorName VARCHAR(255),
        Brand INT,
        Description VARCHAR(255),
        PurchasePrice DECIMAL(10,2),
        ActualPrice DECIMAL(10,2),
        Volume DECIMAL(10,2),
        TotalPurchaseQuantity INT,
        TotalPurchaseDollars DECIMAL(15,2),
        TotalSalesQuantity INT,
        TotalSalesDollars DECIMAL(15,2), 
        TotalSalesPrice DECIMAL(15,2),
        TotalExciseTax DECIMAL(15,2),
        FreightCost DECIMAL(15,2),
        GrossProfit DECIMAL(15,2),
        ProfitMargin DECIMAL(15,2),
        StockTurnover DECIMAL(15,2),
        SalesToPurchaseRate DECIMAL(15,2),
        PRIMARY KEY (VendorNumber, Brand)
    )
    """)
    conn.execute(query)
    
    conn.commit()

# %%
vendor_sales_summary.to_csv("vendor_sales_summary_backup.csv", index=False)

# %%
import numpy as np

# 1. Replace positive and negative infinity with NaN (Not a Number)
vendor_sales_summary.replace([np.inf, -np.inf], np.nan, inplace=True)

# 2. Fill the new NaNs (and any other empty cells) with 0
vendor_sales_summary.fillna(0, inplace=True)

# 3. Double checking , this should return 0 if all infs are gone
print(f"Infinity values left: {np.isinf(vendor_sales_summary.select_dtypes(include=np.number)).values.sum()}")
# Out:
# Infinity values left: 0

# %%
vendor_sales_summary.to_sql(
    "vendor_sales_summary", 
    con=engine, 
    if_exists="replace", 
    index=False, 
    chunksize=5000
)
# Out:
# 10692

# %%
display(vendor_sales_summary.head(10))
display(vendor_sales_summary.tail())
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
# 5           480           BACARDI USA INC   3858         Grey Goose Vodka
# 6         17035         PERNOD RICARD USA   2589    Jameson Irish Whiskey
# 7          3960  DIAGEO NORTH AMERICA INC   3102        Smirnoff Traveler
# 8          3960  DIAGEO NORTH AMERICA INC   3489                Tanqueray
# 9         12546   JIM BEAM BRANDS COMPANY   1376                 Jim Beam
#
#    PurchasePrice  ActualPrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          26.27        36.99               145080.0            3811251.60
# ...
